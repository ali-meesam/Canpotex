# %%
from datapipeline import DataFeed
import os
import pandas as pd
from datetime import datetime

# %%
ben_comp = pd.read_excel("DataFeeds/Ben_Predictions.xlsx",index_col=0,parse_dates=True)

# %%
self = DataFeed()

# %%
brazil = self.get_BrazilCFR
brazil.dropna(inplace=True)

# %%
seasia = self.get_SEAsiaCFR
seasia.dropna(inplace=True)

# %%
foodpriceindex = self.get_food_price_index
foodpriceindex.dropna(inplace=True)

# %%
eurusd = self.get_eurusd
eurusd.dropna(inplace=True)

# %%
cpi = self.get_g20_cpi
cpi.dropna(inplace=True)

# %%
gdp = self.get_gdp
gdp.dropna(inplace=True)

# %%
netback = self.get_historical_netback
netback.dropna(inplace=True)

# %%
minenetback = self.get_historical_mineNetback
minenetback.dropna(inplace=True)

# %%
naturalgas = self.get_natural_gas
naturalgas.dropna(inplace=True)

# %%
ethanol = self.get_ethanol
ethanol.dropna(inplace=True)

# %%
fertilizerprod = self.get_total_fertilizer_production
fertilizerprod.dropna(inplace=True)

# %%
freightcost = self.get_freightCost
freightcost.dropna(inplace=True)

# %%
interim = self.get_interimPricing
interim.dropna(inplace=True)

# %%
_vars = [brazil,seasia,foodpriceindex,eurusd,cpi,gdp,netback,minenetback,naturalgas,ethanol,fertilizerprod,freightcost,interim]

# %%
counts = [v.iloc[0].name for v in _vars]

# %%
# GET THE SMALLEST DATA SET
times = _vars[counts.index(max(counts))].index.tolist()

# %%
from models import ActualNetback, BrazilCFR

# %%
curr_month = 7
curr_year = 2022

# %%
m = ActualNetback()

# %%
predictions = []
for t in times:
    month = t.month
    year = t.year
    if year==curr_year:
        if month<=curr_month:
            predictions.append([year,month,m.predict(month,year)])
    else:
        predictions.append([year,month,m.predict(month,year)])
# Out:
# Predicting Actual Netback >> 12 / 2014...
# Predicting MineNetback >> 12 / 2014...
# Predicting SE Asia >> 12 / 2014...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:05<00:00, 3437.62it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     332.279393
# std        3.314731
# min      321.440904
# 25%      329.980579
# 50%      332.248544
# 75%      334.615688
# max      343.680563
# **************************************************
# Max Density -->>> $331.87
# Predicting Brazil >> 12 / 2014...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:06<00:00, 3023.65it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     376.843817
# std       12.126781
# min      333.948648
# 25%      368.544173
# 50%      376.835614
# 75%      385.258447
# max      420.148622
# **************************************************
# Max Density -->>> $376.79
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 19521.45it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     274.450838
# std        3.275822
# min      263.580320
# 25%      272.174756
# 50%      274.447165
# 75%      276.744367
# max      284.811856
# **************************************************
# Max Density -->>> $273.66
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 12477.75it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     250.957874
# std        5.136509
# min      235.077843
# 25%      247.387974
# 50%      250.998498
# 75%      254.599042
# max      267.244492
# **************************************************
# Max Density -->>> $250.48
# Predicting Actual Netback >> 1 / 2015...
# Predicting MineNetback >> 1 / 2015...
# Predicting SE Asia >> 1 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10667.26it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     319.791648
# std        3.933481
# min      304.222787
# 25%      317.093248
# 50%      319.775047
# 75%      322.525692
# max      333.254353
# **************************************************
# Max Density -->>> $319.64
# Predicting Brazil >> 1 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6224.22it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     366.447068
# std       12.033070
# min      326.491570
# 25%      358.145915
# 50%      366.371745
# 75%      374.778384
# max      407.488825
# **************************************************
# Max Density -->>> $366.42
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21564.22it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     255.356362
# std        3.345223
# min      244.424823
# 25%      253.006187
# 50%      255.343329
# 75%      257.654925
# max      267.036586
# **************************************************
# Max Density -->>> $255.21
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13731.20it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     234.013362
# std        4.266835
# min      220.485055
# 25%      230.990283
# 50%      233.995687
# 75%      237.060653
# max      247.169333
# **************************************************
# Max Density -->>> $233.16
# Predicting Actual Netback >> 2 / 2015...
# Predicting MineNetback >> 2 / 2015...
# Predicting SE Asia >> 2 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10671.86it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     318.683390
# std        4.290985
# min      303.197639
# 25%      315.717147
# 50%      318.708461
# 75%      321.641247
# max      333.446239
# **************************************************
# Max Density -->>> $319.2
# Predicting Brazil >> 2 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6279.16it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     352.827891
# std       11.376616
# min      312.434464
# 25%      344.977825
# 50%      352.891405
# 75%      360.712419
# max      392.408355
# **************************************************
# Max Density -->>> $353.62
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21424.91it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     253.025437
# std        3.324342
# min      240.937166
# 25%      250.751091
# 50%      252.995904
# 75%      255.273791
# max      265.361035
# **************************************************
# Max Density -->>> $252.78
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14115.87it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     252.072680
# std        4.138057
# min      239.193291
# 25%      249.184630
# 50%      252.057212
# 75%      254.951103
# max      265.143927
# **************************************************
# Max Density -->>> $251.93
# Predicting Actual Netback >> 3 / 2015...
# Predicting MineNetback >> 3 / 2015...
# Predicting SE Asia >> 3 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10989.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     320.681024
# std        4.284787
# min      306.485121
# 25%      317.689053
# 50%      320.700939
# 75%      323.660604
# max      336.950572
# **************************************************
# Max Density -->>> $320.89
# Predicting Brazil >> 3 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6496.78it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     325.355566
# std       11.190960
# min      284.395169
# 25%      317.487417
# 50%      325.303997
# 75%      333.183315
# max      364.346150
# **************************************************
# Max Density -->>> $327.17
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 19403.37it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     242.897087
# std        3.170821
# min      231.070190
# 25%      240.737498
# 50%      242.869147
# 75%      245.068822
# max      254.526991
# **************************************************
# Max Density -->>> $242.68
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14105.05it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     241.622495
# std        4.028037
# min      228.415873
# 25%      238.776965
# 50%      241.606346
# 75%      244.457887
# max      254.168266
# **************************************************
# Max Density -->>> $241.11
# Predicting Actual Netback >> 4 / 2015...
# Predicting MineNetback >> 4 / 2015...
# Predicting SE Asia >> 4 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10071.98it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     323.867820
# std        4.544798
# min      308.432736
# 25%      320.691340
# 50%      323.833671
# 75%      327.005273
# max      339.611805
# **************************************************
# Max Density -->>> $323.74
# Predicting Brazil >> 4 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6571.22it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     333.732718
# std       11.389362
# min      293.291255
# 25%      325.753335
# 50%      333.737090
# 75%      341.610055
# max      374.481491
# **************************************************
# Max Density -->>> $333.81
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22287.10it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     253.176079
# std        3.472131
# min      239.948842
# 25%      250.767731
# 50%      253.169640
# 75%      255.581173
# max      264.990409
# **************************************************
# Max Density -->>> $253.35
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13781.55it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     239.449168
# std        3.701065
# min      227.810280
# 25%      236.840049
# 50%      239.466395
# 75%      242.055017
# max      250.410464
# **************************************************
# Max Density -->>> $239.63
# Predicting Actual Netback >> 5 / 2015...
# Predicting MineNetback >> 5 / 2015...
# Predicting SE Asia >> 5 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 11099.16it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     333.856667
# std        3.770563
# min      320.537953
# 25%      331.217550
# 50%      333.854455
# 75%      336.496103
# max      347.078651
# **************************************************
# Max Density -->>> $333.73
# Predicting Brazil >> 5 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6195.92it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     324.797497
# std       12.042772
# min      283.165334
# 25%      316.505021
# 50%      324.780868
# 75%      333.154682
# max      367.764772
# **************************************************
# Max Density -->>> $324.87
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21976.37it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     253.894538
# std        3.564532
# min      241.443368
# 25%      251.428903
# 50%      253.882669
# 75%      256.374035
# max      266.757901
# **************************************************
# Max Density -->>> $253.82
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14251.04it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     240.804527
# std        3.152147
# min      231.128454
# 25%      238.587340
# 50%      240.798859
# 75%      243.037310
# max      250.558312
# **************************************************
# Max Density -->>> $240.63
# Predicting Actual Netback >> 6 / 2015...
# Predicting MineNetback >> 6 / 2015...
# Predicting SE Asia >> 6 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10930.45it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     319.955873
# std        3.352168
# min      309.064129
# 25%      317.595476
# 50%      319.978079
# 75%      322.304979
# max      331.215137
# **************************************************
# Max Density -->>> $320.21
# Predicting Brazil >> 6 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6337.81it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     337.208662
# std       12.823825
# min      294.681753
# 25%      328.346781
# 50%      337.220803
# 75%      346.020329
# max      380.448726
# **************************************************
# Max Density -->>> $338.34
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22702.73it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     251.536629
# std        3.511709
# min      238.626044
# 25%      249.129115
# 50%      251.538621
# 75%      253.946331
# max      264.774614
# **************************************************
# Max Density -->>> $251.83
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14291.49it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     241.591472
# std        2.821057
# min      232.830445
# 25%      239.594273
# 50%      241.603597
# 75%      243.573212
# max      251.405007
# **************************************************
# Max Density -->>> $241.91
# Predicting Actual Netback >> 7 / 2015...
# Predicting MineNetback >> 7 / 2015...
# Predicting SE Asia >> 7 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10921.94it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     314.712890
# std        3.280636
# min      303.754857
# 25%      312.415411
# 50%      314.731109
# 75%      317.021608
# max      324.728002
# **************************************************
# Max Density -->>> $314.77
# Predicting Brazil >> 7 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6573.53it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     333.793739
# std       12.958199
# min      289.575688
# 25%      324.929715
# 50%      333.739833
# 75%      342.676272
# max      382.862157
# **************************************************
# Max Density -->>> $331.64
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22878.27it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     246.676410
# std        3.728027
# min      233.741009
# 25%      244.109892
# 50%      246.656937
# 75%      249.243146
# max      259.755967
# **************************************************
# Max Density -->>> $246.31
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14392.71it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     227.084149
# std        2.933178
# min      218.089971
# 25%      225.004470
# 50%      227.094541
# 75%      229.146913
# max      236.827893
# **************************************************
# Max Density -->>> $227.37
# Predicting Actual Netback >> 8 / 2015...
# Predicting MineNetback >> 8 / 2015...
# Predicting SE Asia >> 8 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10798.69it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     303.851431
# std        2.918513
# min      294.435364
# 25%      301.802005
# 50%      303.839182
# 75%      305.880235
# max      312.975882
# **************************************************
# Max Density -->>> $304.02
# Predicting Brazil >> 8 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6514.81it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     291.700685
# std       12.329118
# min      247.957263
# 25%      283.128122
# 50%      291.724713
# 75%      300.189160
# max      334.672558
# **************************************************
# Max Density -->>> $292.44
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22847.89it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     227.981235
# std        4.071266
# min      214.710561
# 25%      225.114381
# 50%      227.973375
# 75%      230.812533
# max      241.061561
# **************************************************
# Max Density -->>> $228.02
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14061.08it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     219.737141
# std        2.880256
# min      210.644971
# 25%      217.683908
# 50%      219.731663
# 75%      221.804216
# max      227.848514
# **************************************************
# Max Density -->>> $219.4
# Predicting Actual Netback >> 9 / 2015...
# Predicting MineNetback >> 9 / 2015...
# Predicting SE Asia >> 9 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10917.33it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     307.393580
# std        3.353703
# min      296.655560
# 25%      305.071103
# 50%      307.360090
# 75%      309.747475
# max      317.965492
# **************************************************
# Max Density -->>> $307.46
# Predicting Brazil >> 9 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6465.60it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     289.517068
# std       11.309604
# min      250.728652
# 25%      281.648082
# 50%      289.576601
# 75%      297.475500
# max      327.731319
# **************************************************
# Max Density -->>> $290.85
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21595.69it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     230.617661
# std        4.514028
# min      216.095377
# 25%      227.453197
# 50%      230.628487
# 75%      233.791477
# max      245.834069
# **************************************************
# Max Density -->>> $229.68
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14398.93it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     223.158084
# std        2.867441
# min      214.811777
# 25%      221.133349
# 50%      223.131362
# 75%      225.189309
# max      232.076676
# **************************************************
# Max Density -->>> $222.98
# Predicting Actual Netback >> 10 / 2015...
# Predicting MineNetback >> 10 / 2015...
# Predicting SE Asia >> 10 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10797.22it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     301.494308
# std        3.850891
# min      287.491380
# 25%      298.796649
# 50%      301.496790
# 75%      304.174632
# max      313.995535
# **************************************************
# Max Density -->>> $301.25
# Predicting Brazil >> 10 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6552.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     270.933329
# std       11.317970
# min      236.024811
# 25%      262.948047
# 50%      270.945172
# 75%      278.882158
# max      308.901808
# **************************************************
# Max Density -->>> $270.93
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22469.68it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     221.086493
# std        4.880752
# min      204.897978
# 25%      217.658613
# 50%      221.139562
# 75%      224.457995
# max      237.617104
# **************************************************
# Max Density -->>> $221.62
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13776.69it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     225.404117
# std        2.897749
# min      216.034430
# 25%      223.356839
# 50%      225.436061
# 75%      227.428917
# max      234.276068
# **************************************************
# Max Density -->>> $225.94
# Predicting Actual Netback >> 11 / 2015...
# Predicting MineNetback >> 11 / 2015...
# Predicting SE Asia >> 11 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10555.27it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     283.164671
# std        4.814104
# min      267.838072
# 25%      279.817933
# 50%      283.131404
# 75%      286.539549
# max      299.108754
# **************************************************
# Max Density -->>> $283.25
# Predicting Brazil >> 11 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6468.94it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     274.896493
# std       11.522031
# min      237.944851
# 25%      266.870873
# 50%      274.864105
# 75%      282.970701
# max      309.167967
# **************************************************
# Max Density -->>> $275.34
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22583.24it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     215.111521
# std        5.124118
# min      198.611706
# 25%      211.542525
# 50%      215.076872
# 75%      218.683005
# max      232.232001
# **************************************************
# Max Density -->>> $214.38
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13915.19it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     216.155043
# std        3.015244
# min      206.343981
# 25%      214.030523
# 50%      216.146101
# 75%      218.297847
# max      225.317551
# **************************************************
# Max Density -->>> $215.89
# Predicting Actual Netback >> 12 / 2015...
# Predicting MineNetback >> 12 / 2015...
# Predicting SE Asia >> 12 / 2015...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10869.45it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     270.223401
# std        5.702385
# min      252.131915
# 25%      266.180745
# 50%      270.205955
# 75%      274.229780
# max      289.491659
# **************************************************
# Max Density -->>> $270.62
# Predicting Brazil >> 12 / 2015...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6449.14it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     258.093559
# std       11.840127
# min      221.090943
# 25%      249.839243
# 50%      258.012247
# 75%      266.401541
# max      296.549184
# **************************************************
# Max Density -->>> $257.38
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22407.90it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     204.124122
# std        5.524348
# min      185.201529
# 25%      200.299671
# 50%      204.092548
# 75%      207.922290
# max      224.263503
# **************************************************
# Max Density -->>> $204.07
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13955.02it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     197.088267
# std        4.031822
# min      185.427104
# 25%      194.239959
# 50%      197.100132
# 75%      199.920825
# max      209.308170
# **************************************************
# Max Density -->>> $197.2
# Predicting Actual Netback >> 1 / 2016...
# Predicting MineNetback >> 1 / 2016...
# Predicting SE Asia >> 1 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10791.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     280.478735
# std        6.754578
# min      259.071724
# 25%      275.649665
# 50%      280.505455
# 75%      285.276958
# max      301.404349
# **************************************************
# Max Density -->>> $279.86
# Predicting Brazil >> 1 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6502.37it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     214.041940
# std       12.802901
# min      171.831389
# 25%      205.014717
# 50%      214.088981
# 75%      223.038039
# max      255.092750
# **************************************************
# Max Density -->>> $216.05
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22301.01it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     185.703674
# std        6.233345
# min      164.159958
# 25%      181.356574
# 50%      185.673533
# 75%      190.002290
# max      207.123435
# **************************************************
# Max Density -->>> $185.34
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14265.36it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     183.278628
# std        5.337092
# min      167.677856
# 25%      179.534091
# 50%      183.271209
# 75%      187.069926
# max      200.068093
# **************************************************
# Max Density -->>> $183.06
# Predicting Actual Netback >> 2 / 2016...
# Predicting MineNetback >> 2 / 2016...
# Predicting SE Asia >> 2 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10927.97it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     273.952813
# std        8.232372
# min      249.872916
# 25%      268.124108
# 50%      274.010496
# 75%      279.672001
# max      298.483139
# **************************************************
# Max Density -->>> $274.81
# Predicting Brazil >> 2 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 5514.25it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     188.751741
# std       14.573163
# min      142.457470
# 25%      178.622694
# 50%      188.786035
# 75%      198.951942
# max      234.127790
# **************************************************
# Max Density -->>> $189.49
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 18745.80it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     173.944168
# std        7.204824
# min      149.681085
# 25%      168.991775
# 50%      173.913882
# 75%      178.882469
# max      198.579890
# **************************************************
# Max Density -->>> $173.69
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 11564.99it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     176.208095
# std        6.271062
# min      156.902043
# 25%      171.782626
# 50%      176.250054
# 75%      180.625837
# max      195.408595
# **************************************************
# Max Density -->>> $176.66
# Predicting Actual Netback >> 3 / 2016...
# Predicting MineNetback >> 3 / 2016...
# Predicting SE Asia >> 3 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:02<00:00, 8542.16it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     270.085836
# std        9.415959
# min      242.630273
# 25%      263.311563
# 50%      270.022114
# 75%      276.781711
# max      297.428722
# **************************************************
# Max Density -->>> $269.86
# Predicting Brazil >> 3 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6051.73it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     169.866452
# std       16.222011
# min      119.558171
# 25%      158.364096
# 50%      169.842799
# 75%      181.524537
# max      216.911969
# **************************************************
# Max Density -->>> $170.09
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21571.94it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     162.301945
# std        8.025538
# min      134.377049
# 25%      156.747243
# 50%      162.353735
# 75%      167.956664
# max      190.687401
# **************************************************
# Max Density -->>> $162.93
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13453.95it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     149.489096
# std        8.764693
# min      122.666947
# 25%      143.380712
# 50%      149.483291
# 75%      155.642465
# max      176.574292
# **************************************************
# Max Density -->>> $149.24
# Predicting Actual Netback >> 4 / 2016...
# Predicting MineNetback >> 4 / 2016...
# Predicting SE Asia >> 4 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10465.14it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     269.717469
# std       10.118754
# min      241.341558
# 25%      262.528877
# 50%      269.646548
# 75%      276.892429
# max      299.135484
# **************************************************
# Max Density -->>> $269.37
# Predicting Brazil >> 4 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6303.41it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     205.461864
# std       16.333777
# min      157.774864
# 25%      193.818064
# 50%      205.528546
# 75%      217.145987
# max      253.230381
# **************************************************
# Max Density -->>> $209.61
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21305.05it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     183.625907
# std        8.366952
# min      155.700778
# 25%      177.785226
# 50%      183.618129
# 75%      189.405737
# max      211.746110
# **************************************************
# Max Density -->>> $183.11
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13524.65it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     149.072989
# std       11.047311
# min      116.602145
# 25%      141.264395
# 50%      149.080303
# 75%      156.800367
# max      182.648706
# **************************************************
# Max Density -->>> $148.9
# Predicting Actual Netback >> 5 / 2016...
# Predicting MineNetback >> 5 / 2016...
# Predicting SE Asia >> 5 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10586.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     260.131509
# std       10.930084
# min      229.974913
# 25%      252.273711
# 50%      260.152707
# 75%      267.886203
# max      292.365177
# **************************************************
# Max Density -->>> $261.11
# Predicting Brazil >> 5 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6257.19it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     198.500321
# std       16.260856
# min      151.762087
# 25%      186.916920
# 50%      198.614294
# 75%      210.153968
# max      244.328757
# **************************************************
# Max Density -->>> $198.69
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22019.93it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     175.135442
# std        8.588571
# min      146.989962
# 25%      169.146058
# 50%      175.153110
# 75%      181.126719
# max      203.178970
# **************************************************
# Max Density -->>> $175.7
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13548.01it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     150.412313
# std       12.223969
# min      112.311013
# 25%      141.839823
# 50%      150.402944
# 75%      159.074066
# max      187.100802
# **************************************************
# Max Density -->>> $150.68
# Predicting Actual Netback >> 6 / 2016...
# Predicting MineNetback >> 6 / 2016...
# Predicting SE Asia >> 6 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10907.88it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     251.988280
# std       11.885514
# min      215.379761
# 25%      243.539851
# 50%      251.966761
# 75%      260.505236
# max      287.103704
# **************************************************
# Max Density -->>> $251.46
# Predicting Brazil >> 6 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6525.75it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     202.273519
# std       15.682439
# min      157.070282
# 25%      191.292601
# 50%      202.299240
# 75%      213.405353
# max      248.500914
# **************************************************
# Max Density -->>> $202.33
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22071.53it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     171.312569
# std        8.632881
# min      142.427593
# 25%      165.381333
# 50%      171.281047
# 75%      177.205035
# max      199.198917
# **************************************************
# Max Density -->>> $171.55
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14165.16it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     145.499652
# std       12.790799
# min      105.089913
# 25%      136.490244
# 50%      145.679550
# 75%      154.529074
# max      185.395234
# **************************************************
# Max Density -->>> $146.77
# Predicting Actual Netback >> 7 / 2016...
# Predicting MineNetback >> 7 / 2016...
# Predicting SE Asia >> 7 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10958.76it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     257.879905
# std       12.294004
# min      222.693194
# 25%      249.157434
# 50%      257.797049
# 75%      266.555786
# max      295.107281
# **************************************************
# Max Density -->>> $258.83
# Predicting Brazil >> 7 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6531.97it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     199.930572
# std       14.664695
# min      155.938150
# 25%      189.400693
# 50%      199.899888
# 75%      210.405359
# max      244.836835
# **************************************************
# Max Density -->>> $198.87
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21996.70it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     170.503859
# std        8.484050
# min      141.191236
# 25%      164.639721
# 50%      170.473365
# 75%      176.421334
# max      198.596979
# **************************************************
# Max Density -->>> $170.64
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14004.40it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     138.349327
# std       13.832574
# min       96.936530
# 25%      128.679744
# 50%      138.342834
# 75%      148.162982
# max      180.478907
# **************************************************
# Max Density -->>> $137.12
# Predicting Actual Netback >> 8 / 2016...
# Predicting MineNetback >> 8 / 2016...
# Predicting SE Asia >> 8 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10879.76it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     246.620947
# std       12.271041
# min      210.143580
# 25%      237.762785
# 50%      246.609670
# 75%      255.373741
# max      283.844547
# **************************************************
# Max Density -->>> $247.07
# Predicting Brazil >> 8 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6447.38it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     196.196818
# std       13.734041
# min      153.373527
# 25%      186.505047
# 50%      196.212374
# 75%      205.862565
# max      236.230290
# **************************************************
# Max Density -->>> $195.88
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22243.96it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     163.969411
# std        8.046597
# min      137.368736
# 25%      158.432006
# 50%      163.914727
# 75%      169.609092
# max      191.818274
# **************************************************
# Max Density -->>> $163.78
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14046.80it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     134.719803
# std       14.143390
# min       91.500869
# 25%      124.813043
# 50%      134.722827
# 75%      144.698015
# max      179.296922
# **************************************************
# Max Density -->>> $135.31
# Predicting Actual Netback >> 9 / 2016...
# Predicting MineNetback >> 9 / 2016...
# Predicting SE Asia >> 9 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10958.57it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     259.606319
# std       11.780320
# min      224.703669
# 25%      251.165001
# 50%      259.547618
# 75%      267.934591
# max      294.600604
# **************************************************
# Max Density -->>> $260.56
# Predicting Brazil >> 9 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6451.90it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     199.410979
# std       12.809282
# min      156.524686
# 25%      190.446428
# 50%      199.498051
# 75%      208.373072
# max      243.339848
# **************************************************
# Max Density -->>> $200.89
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22398.72it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     172.611397
# std        7.357701
# min      147.197586
# 25%      167.570170
# 50%      172.608444
# 75%      177.749638
# max      197.229929
# **************************************************
# Max Density -->>> $172.76
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 12813.07it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     146.275184
# std       13.724248
# min      103.561746
# 25%      136.678008
# 50%      146.276091
# 75%      155.936970
# max      189.118094
# **************************************************
# Max Density -->>> $145.91
# Predicting Actual Netback >> 10 / 2016...
# Predicting MineNetback >> 10 / 2016...
# Predicting SE Asia >> 10 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10870.48it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     259.083740
# std       10.484432
# min      227.917089
# 25%      251.675549
# 50%      259.039404
# 75%      266.518029
# max      293.849668
# **************************************************
# Max Density -->>> $258.84
# Predicting Brazil >> 10 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6539.37it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     214.905595
# std       11.647239
# min      176.126449
# 25%      206.759945
# 50%      214.952624
# 75%      223.040476
# max      255.017922
# **************************************************
# Max Density -->>> $214.86
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21833.99it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     178.001200
# std        6.438842
# min      155.579249
# 25%      173.540399
# 50%      178.018146
# 75%      182.522343
# max      199.055902
# **************************************************
# Max Density -->>> $177.8
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13604.62it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     147.724679
# std       12.397525
# min      108.308765
# 25%      139.066213
# 50%      147.695645
# 75%      156.434581
# max      187.044580
# **************************************************
# Max Density -->>> $148.39
# Predicting Actual Netback >> 11 / 2016...
# Predicting MineNetback >> 11 / 2016...
# Predicting SE Asia >> 11 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10908.96it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     248.517313
# std        9.252269
# min      219.786651
# 25%      241.975281
# 50%      248.537467
# 75%      255.055336
# max      276.834923
# **************************************************
# Max Density -->>> $248.6
# Predicting Brazil >> 11 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6520.93it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     207.207662
# std        9.642642
# min      173.341719
# 25%      200.642660
# 50%      207.157418
# 75%      213.809781
# max      246.461882
# **************************************************
# Max Density -->>> $206.9
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22158.52it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     170.104333
# std        5.385664
# min      150.499901
# 25%      166.403524
# 50%      170.122492
# 75%      173.860211
# max      188.353391
# **************************************************
# Max Density -->>> $169.77
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14093.88it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     148.816690
# std       10.348937
# min      115.846982
# 25%      141.517494
# 50%      148.826829
# 75%      156.081901
# max      181.398361
# **************************************************
# Max Density -->>> $149.48
# Predicting Actual Netback >> 12 / 2016...
# Predicting MineNetback >> 12 / 2016...
# Predicting SE Asia >> 12 / 2016...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10931.54it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     257.111063
# std        8.124349
# min      230.272047
# 25%      251.405524
# 50%      257.037464
# 75%      262.756354
# max      282.632280
# **************************************************
# Max Density -->>> $256.19
# Predicting Brazil >> 12 / 2016...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6462.29it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     200.816710
# std        7.768714
# min      174.325446
# 25%      195.475770
# 50%      200.756708
# 75%      206.066578
# max      227.607411
# **************************************************
# Max Density -->>> $200.49
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22422.24it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     171.110718
# std        4.385438
# min      157.012189
# 25%      168.062244
# 50%      171.073112
# 75%      174.155113
# max      185.914281
# **************************************************
# Max Density -->>> $170.74
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13791.69it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     147.460543
# std        8.522807
# min      121.611471
# 25%      141.357115
# 50%      147.487175
# 75%      153.433604
# max      178.333016
# **************************************************
# Max Density -->>> $147.53
# Predicting Actual Netback >> 1 / 2017...
# Predicting MineNetback >> 1 / 2017...
# Predicting SE Asia >> 1 / 2017...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 11029.50it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     252.748386
# std        7.214404
# min      229.346808
# 25%      247.682865
# 50%      252.796168
# 75%      257.832090
# max      277.675876
# **************************************************
# Max Density -->>> $253.17
# Predicting Brazil >> 1 / 2017...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6551.67it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     205.628455
# std        6.353625
# min      183.290883
# 25%      201.253625
# 50%      205.655679
# 75%      210.035789
# max      226.576234
# **************************************************
# Max Density -->>> $206.1
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22420.69it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     165.255886
# std        3.575554
# min      153.068189
# 25%      162.801921
# 50%      165.249337
# 75%      167.706298
# max      177.879735
# **************************************************
# Max Density -->>> $165.25
# ...
#         Predictions
# count  20000.000000
# mean     804.484377
# std       81.215044
# min      600.496155
# 25%      746.389642
# 50%      804.625546
# 75%      862.267346
# max     1009.974446
# **************************************************
# Max Density -->>> $804.01
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21905.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     555.759290
# std       42.433708
# min      425.476267
# 25%      526.211579
# 50%      555.836441
# 75%      585.201550
# max      689.936901
# **************************************************
# Max Density -->>> $561.68
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14179.37it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     469.230809
# std       37.027572
# min      344.546610
# 25%      443.333850
# 50%      469.383032
# 75%      494.911124
# max      586.734921
# **************************************************
# Max Density -->>> $467.34
# Predicting Actual Netback >> 12 / 2021...
# Predicting MineNetback >> 12 / 2021...
# Predicting SE Asia >> 12 / 2021...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 11027.68it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     621.923780
# std       56.057951
# min      482.361613
# 25%      581.612065
# 50%      622.015208
# 75%      661.766418
# max      763.638235
# **************************************************
# Max Density -->>> $619.9
# Predicting Brazil >> 12 / 2021...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6519.87it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     805.012520
# std       82.353294
# min      589.067807
# 25%      746.172293
# 50%      804.938140
# 75%      864.167530
# max     1020.349589
# **************************************************
# Max Density -->>> $803.41
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22218.30it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     551.445323
# std       43.736632
# min      403.870352
# 25%      520.991474
# 50%      551.388935
# 75%      581.606853
# max      691.912702
# **************************************************
# Max Density -->>> $550.49
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14127.21it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     426.431905
# std       39.784814
# min      299.221105
# 25%      398.685178
# 50%      426.495360
# 75%      454.087143
# max      558.135601
# **************************************************
# Max Density -->>> $432.57
# Predicting Actual Netback >> 1 / 2022...
# Predicting MineNetback >> 1 / 2022...
# Predicting SE Asia >> 1 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10780.77it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     631.609008
# std       58.015447
# min      488.261311
# 25%      589.644916
# 50%      631.908593
# 75%      672.836604
# max      776.876495
# **************************************************
# Max Density -->>> $634.01
# Predicting Brazil >> 1 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6533.32it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     801.898264
# std       78.941799
# min      593.216496
# 25%      745.227088
# 50%      801.806875
# 75%      857.237388
# max     1006.492928
# **************************************************
# Max Density -->>> $801.92
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22841.53it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     552.322159
# std       43.294500
# min      407.468528
# 25%      522.212926
# 50%      552.141161
# 75%      582.329321
# max      696.661700
# **************************************************
# Max Density -->>> $550.62
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14140.25it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     540.615364
# std       46.032051
# min      385.132083
# 25%      508.716191
# 50%      541.058327
# 75%      572.664386
# max      699.958676
# **************************************************
# Max Density -->>> $547.27
# Predicting Actual Netback >> 2 / 2022...
# Predicting MineNetback >> 2 / 2022...
# Predicting SE Asia >> 2 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10645.02it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     645.753172
# std       57.029930
# min      504.128108
# 25%      604.361017
# 50%      645.954723
# 75%      687.211058
# max      786.514835
# **************************************************
# Max Density -->>> $646.73
# Predicting Brazil >> 2 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6541.12it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     786.323109
# std       73.539816
# min      596.847128
# 25%      733.898655
# 50%      786.522760
# 75%      839.002867
# max      978.980564
# **************************************************
# Max Density -->>> $790.59
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 21482.25it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     546.199195
# std       41.593811
# min      416.495993
# 25%      517.088726
# 50%      546.130906
# 75%      575.418845
# max      683.869924
# **************************************************
# Max Density -->>> $544.03
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 14003.90it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     565.854863
# std       50.872260
# min      404.285744
# 25%      530.029670
# 50%      565.730253
# 75%      601.837300
# max      735.068284
# **************************************************
# Max Density -->>> $562.06
# Predicting Actual Netback >> 3 / 2022...
# Predicting MineNetback >> 3 / 2022...
# Predicting SE Asia >> 3 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10859.41it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     785.870592
# std       60.532120
# min      636.794450
# 25%      742.540815
# 50%      785.751699
# 75%      829.899935
# max      938.106494
# **************************************************
# Max Density -->>> $781.12
# Predicting Brazil >> 3 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6503.70it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1026.615508
# std       75.973383
# min      820.685187
# 25%      972.429815
# 50%     1026.852974
# 75%     1080.475181
# max     1217.745080
# **************************************************
# Max Density -->>> $1026.77
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22234.44it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     685.066586
# std       43.587767
# min      540.379903
# 25%      654.501452
# 50%      684.906193
# 75%      715.468934
# max      816.049912
# **************************************************
# Max Density -->>> $684.56
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13929.85it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     630.277005
# std       54.794446
# min      448.037297
# 25%      592.000756
# 50%      630.231150
# 75%      668.735490
# max      794.893796
# **************************************************
# Max Density -->>> $631.53
# Predicting Actual Netback >> 4 / 2022...
# Predicting MineNetback >> 4 / 2022...
# Predicting SE Asia >> 4 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10948.25it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     982.390395
# std       71.532711
# min      802.889474
# 25%      931.195003
# 50%      982.161724
# 75%     1034.148528
# max     1162.579892
# **************************************************
# Max Density -->>> $978.05
# Predicting Brazil >> 4 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6309.43it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1205.842122
# std       81.651676
# min      992.997958
# 25%     1146.793819
# 50%     1205.425422
# 75%     1264.954092
# max     1412.311578
# **************************************************
# Max Density -->>> $1203.07
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22471.97it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     869.062879
# std       49.227282
# min      711.185163
# 25%      834.991327
# 50%      868.639003
# 75%      903.371567
# max     1029.309067
# **************************************************
# Max Density -->>> $864.2
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13792.63it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     678.170791
# std       58.688225
# min      495.153825
# 25%      636.792533
# 50%      678.985491
# 75%      719.385656
# max      862.560679
# **************************************************
# Max Density -->>> $686.58
# Predicting Actual Netback >> 5 / 2022...
# Predicting MineNetback >> 5 / 2022...
# Predicting SE Asia >> 5 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10756.90it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1005.241990
# std       76.036573
# min      810.941154
# 25%      950.121827
# 50%     1005.349659
# 75%     1059.286092
# max     1201.204332
# **************************************************
# Max Density -->>> $1012.71
# Predicting Brazil >> 5 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6527.58it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1204.613322
# std       79.172192
# min      980.018748
# 25%     1147.734012
# 50%     1204.393977
# 75%     1261.149437
# max     1415.631694
# **************************************************
# Max Density -->>> $1201.75
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22346.42it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     880.546522
# std       49.900037
# min      718.112848
# 25%      845.688310
# 50%      881.066643
# 75%      915.461358
# max     1037.287741
# **************************************************
# Max Density -->>> $886.33
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13945.93it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     717.091741
# std       60.617171
# min      533.477161
# 25%      674.357921
# 50%      717.961526
# 75%      759.671231
# max      909.580906
# **************************************************
# Max Density -->>> $724.16
# Predicting Actual Netback >> 6 / 2022...
# Predicting MineNetback >> 6 / 2022...
# Predicting SE Asia >> 6 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10680.46it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1003.101037
# std       75.313355
# min      809.102528
# 25%      949.623546
# 50%     1002.103660
# 75%     1056.357145
# max     1196.629226
# **************************************************
# Max Density -->>> $999.37
# Predicting Brazil >> 6 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6555.14it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1102.531106
# std       72.436598
# min      879.408790
# 25%     1051.292692
# 50%     1102.341525
# 75%     1154.387686
# max     1311.204150
# **************************************************
# Max Density -->>> $1100.06
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22209.32it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     834.929535
# std       46.737000
# min      693.243477
# 25%      802.602042
# 50%      834.454234
# 75%      867.447818
# max      978.363508
# **************************************************
# Max Density -->>> $826.96
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13933.58it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     746.563768
# std       62.047292
# min      548.065119
# 25%      702.880338
# 50%      746.669336
# 75%      790.318092
# max      937.154020
# **************************************************
# Max Density -->>> $749.23
# Predicting Actual Netback >> 7 / 2022...
# Predicting MineNetback >> 7 / 2022...
# Predicting SE Asia >> 7 / 2022...
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 10936.74it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     985.669396
# std       71.255120
# min      792.836965
# 25%      934.589217
# 50%      985.813305
# 75%     1036.874854
# max     1167.441054
# **************************************************
# Max Density -->>> $984.26
# Predicting Brazil >> 7 / 2022...
# 100%|██████████████████████████████████████████████████████████████████████████| 20000/20000 [00:03<00:00, 6456.94it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean    1025.474362
# std       67.258279
# min      819.458133
# 25%      977.823259
# 50%     1024.893164
# 75%     1072.969646
# max     1225.456060
# **************************************************
# Max Density -->>> $1022.86
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:00<00:00, 22204.40it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     819.132281
# std       44.350207
# min      681.691204
# 25%      788.244359
# 50%      818.874157
# 75%      850.131199
# max      954.279709
# **************************************************
# Max Density -->>> $816.08
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [00:01<00:00, 13905.88it/s]
# **************************************************
#         Predictions
# count  20000.000000
# mean     715.314034
# std       61.175782
# min      524.540835
# 25%      671.659341
# 50%      715.179175
# 75%      758.713390
# max      901.880584
# **************************************************
# Max Density -->>> $716.61

# %%
netback_comparison = pd.DataFrame(predictions,columns=['Year','Month','Prediction'])
netback_comparison['Interim']= interim[-len(netback_comparison):].InterimPricing.values

# No need to shift since actual is realized by month end
# netback_comparison['Prediction'] = netback_comparison.Prediction.shift(1)

netback_comparison['Actual'] = netback[-len(netback_comparison):]['Netback ($/tonne)'].values

# %%
# netback_comparison['BenPrediction'] = ben_comp.iloc[-len(netback_comparison):].values

# %%
netback_comparison
# Out:
#     Year  Month  Prediction     Interim      Actual
# 0   2014     12      250.48  245.211858  255.122217
# 1   2015      1      233.16  235.073563  252.650688
# 2   2015      2      251.93  258.563176  246.852093
# 3   2015      3      241.11  253.273992  251.170710
# 4   2015      4      239.63  244.882248  244.908093
# ..   ...    ...         ...         ...         ...
# 87  2022      3      631.53  542.513635  580.475858
# 88  2022      4      686.58  580.571322  714.881002
# 89  2022      5      724.16  642.309268  720.468911
# 90  2022      6      749.23  700.956338  712.663293
# 91  2022      7      716.61  696.350225  622.874274
#
# [92 rows x 5 columns]

# %%
# netback_comparison[['Prediction','Actual','Interim','BenPrediction']].plot()
netback_comparison[['Prediction','Actual','Interim']].plot()
# Out:
# <AxesSubplot:>

# %%
netback_comparison['Err-Prediction-Actual'] = (netback_comparison['Actual']/netback_comparison['Prediction']-1)*100
netback_comparison['Err-Interim-Actual'] = (netback_comparison['Actual']/netback_comparison['Interim']-1)*100
# netback_comparison['Err-Ben-Actual'] = (netback_comparison['Actual']/netback_comparison['BenPrediction']-1)*100

# %%
netback_comparison
# Out:
#     Year  Month  Prediction     Interim      Actual  Err-Prediction-Actual  \
# 0   2014     12      250.48  245.211858  255.122217               1.853328
# 1   2015      1      233.16  235.073563  252.650688               8.359362
# 2   2015      2      251.93  258.563176  246.852093              -2.015602
# 3   2015      3      241.11  253.273992  251.170710               4.172664
# 4   2015      4      239.63  244.882248  244.908093               2.202601
# ..   ...    ...         ...         ...         ...                    ...
# 87  2022      3      631.53  542.513635  580.475858              -8.084199
# 88  2022      4      686.58  580.571322  714.881002               4.122025
# 89  2022      5      724.16  642.309268  720.468911              -0.509706
# 90  2022      6      749.23  700.956338  712.663293              -4.880572
# 91  2022      7      716.61  696.350225  622.874274             -13.080438
#
#     Err-Interim-Actual
# 0             4.041550
# 1             7.477287
# 2            -4.529292
# 3            -0.830438
# 4             0.010554
# ..                 ...
# 87            6.997469
# 88           23.134054
# 89           12.168537
# 90            1.670140
# 91          -10.551580
#
# [92 rows x 7 columns]

# %%
# abs(netback_comparison[['Err-Prediction-Actual','Err-Interim-Actual','Err-Ben-Actual']]).plot(kind='bar',title='Error Comparison')
abs(netback_comparison[['Err-Prediction-Actual','Err-Interim-Actual']]).plot(kind='bar',title='Error Comparison')
# Out:
# <AxesSubplot:title={'center':'Error Comparison'}>

# %%
# abs(netback_comparison[['Err-Prediction-Actual','Err-Interim-Actual','Err-Ben-Actual']]).plot(kind='kde',title='Error Comparison')
abs(netback_comparison[['Err-Prediction-Actual','Err-Interim-Actual']]).plot(kind='kde',title='Error Comparison')
# Out:
# <AxesSubplot:title={'center':'Error Comparison'}, ylabel='Density'>

# %%
m.kde_max_density(netback_comparison[['Err-Prediction-Actual','Err-Interim-Actual']])
# Out:
# {'Err-Prediction-Actual': -0.006045780429104752,
#  'Err-Interim-Actual': 0.7206132733794561}
