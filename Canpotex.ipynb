# %%
import pandas as pd
from datetime import datetime
import os

# %%
years = ['2019',
 '2020',
 '2021',
 '2022']

# %%
def update_canpotex_interim_pricing(r,update=False):
    """r: root folder"""
    dest = os.path.join(r'C:\Users\tmpMeesam\OneDrive - Nutrien\NPK-IT\Projects\Canpotex\Data',"Interim_Pricing.csv")
    main_df = pd.read_csv(dest,index_col=0)
    if update:
        paths = [os.path.join(r,i) for i in os.listdir(r) if "Interim" in i]
        if len(paths)>0:
            main_df = pd.DataFrame()
            for p in paths:
                df = pd.read_excel(p,header=15).iloc[2:13,2:]
#                 Check for New Entries in Main_df
                df= df[[i not in main_df.Date.tolist() for i in df.Date]]
                if len(df)>0:
                    d = os.path.basename(p).rstrip('.xlsx').split(" ")[-2:]
                    df['Date'] = datetime.strptime(" ".join(d),"%B %Y")
                    main_df = main_df.append(df,ignore_index=True)
            main_df.sort_values("Date",inplace=True)
            main_df.reset_index(drop=True,inplace=True)
#             Saving
            main_df.to_csv(dest)
    return main_df

# %%
for year in years:
    r = f"C:\\Users\\tmpMeesam\\Nutrien\\Ben Bergermann - Canpotex\\{year}\\"
    update_canpotex_interim_pricing(r,update=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
#       1 for year in years:
#       2     r = f"C:\\Users\\tmpMeesam\\Nutrien\\Ben Bergermann - Canpotex\\{year}\\"
# ----> 3     update_canpotex_interim_pricing(r,update=True)
#
# Input In [86], in update_canpotex_interim_pricing(r, update)
#       8             main_df = pd.DataFrame()
#       9             for p in paths:
# ---> 10                 df = pd.read_excel(p,header=15).iloc[2:13,2:]
#      11 #                 Check for New Entries in Main_df
#      12                 df= df[[i not in main_df.Date.tolist() for i in df.Date]]
#
# File ~\Anaconda3\envs\sandbox\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\envs\sandbox\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~\Anaconda3\envs\sandbox\lib\site-packages\pandas\io\excel\_base.py:1380, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
# -> 1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#    1385 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1386 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
paths = [os.path.join(r,i) for i in os.listdir(r) if "Volumes  Netback Forecast - Nutrien.xlsx" in i]

# %%
p = paths[0]

# %%
pd.read_excel(p,header=[1,2])
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Jan-19\n Forecast  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1                mt
# 0         All Regions        All_Regions         All_Grades     823897.310000
# 1                Asia                 AS         All_Grades     576507.000000
# 2                 NaN                 AS             STD _P     411189.000000
# 3                 NaN                 AS             PRM _P     165318.000000
# 4       Latin America                 LA         All_Grades     142201.000000
# 5                 NaN                 LA             STD _P      16205.000000
# 6                 NaN                 LA             PRM _P     125996.000000
# 7             Oceania                 OC         All_Grades      20596.000000
# 8                 NaN                 OC             STD _P          0.000000
# 9                 NaN                 OC             PRM _P      20596.000000
# 10             Europe                 EU         All_Grades      84593.310000
# 11                NaN                 EU             STD _P       7112.000000
# 12                NaN                 EU             PRM _P      77481.310000
# 13             Africa                 AF         All_Grades          0.000000
# 14                NaN                 AF             STD _P          0.000000
# 15                NaN                 AF             PRM _P          0.000000
# 16                NaN                NaN                NaN               NaN
